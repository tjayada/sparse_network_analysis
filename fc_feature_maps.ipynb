# %% [markdown]
# # Import Libraries

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import networkx as nx
import copy
import warnings
warnings.filterwarnings('ignore')

# %%
from load_models import *
from syngem_utils import *
from loader import *

# %%
torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# # Get units

# %%
gem_50 = load_gem_50_first_layer_units()
gem_20 = load_gem_20_first_layer_units()
gem_10 = load_gem_10_first_layer_units()
gem_5 = load_gem_5_first_layer_units()
gem_2 = load_gem_2_first_layer_units()
# Out:
# => Reading YAML config from Configs/hypercube/resnet20/resnet20_quantized_iter_hc_target_sparsity_1_4_highreg.yml
# => Reading YAML config from Configs/synflow_fc.yml

# %%
syn_50 = load_syn_50_first_layer_units()
syn_20 = load_syn_20_first_layer_units()
syn_10 = load_syn_10_first_layer_units()
syn_5 = load_syn_5_first_layer_units()
syn_2 = load_syn_2_first_layer_units()

# %%
rnd_50 = load_rnd_50_first_layer_units()
rnd_20 = load_rnd_20_first_layer_units()
rnd_10 = load_rnd_10_first_layer_units()
rnd_5 = load_rnd_5_first_layer_units()
rnd_2 = load_rnd_2_first_layer_units()

# %% [markdown]
# # Plot Gem-Miner

# %%
plot_units(gem_50, "gem-miner", 50)

# %%
plot_units(gem_20, "gem-miner", 20)

# %%
plot_units(gem_10, "gem-miner", 10)

# %%
plot_units(gem_5, "gem-miner", 5)

# %%
plot_units(gem_2, "gem-miner", 2)

# %% [markdown]
# # Synflow

# %%
plot_units(syn_50, "synflow", 50)

# %%
plot_units(syn_20, "synflow", 20)

# %%
plot_units(syn_10, "synflow", 10)

# %%
plot_units(syn_5, "synflow", 5)

# %%
plot_units(syn_2, "synflow", 2)

# %% [markdown]
# # Random

# %%
plot_units(rnd_50, "random", 50)

# %%
plot_units(rnd_20, "random", 20)

# %%
plot_units(rnd_10, "random", 10)

# %%
plot_units(rnd_5, "random", 5)

# %%
plot_units(rnd_2, "random", 2)
