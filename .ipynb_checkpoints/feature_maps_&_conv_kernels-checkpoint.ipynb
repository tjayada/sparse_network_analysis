# %% [markdown]
# # Import Libraries

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import networkx as nx
import copy
import warnings
warnings.filterwarnings('ignore')

# %%
from syngem_utils import *
from loader import *

# %%
torch.manual_seed(42)
np.random.seed(42)

# %% [markdown]
# # Get units

# %%
gem_50 = load_gem_first_layer_units(50)
gem_20 = load_gem_first_layer_units(20)
gem_10 = load_gem_first_layer_units(10)
gem_5  = load_gem_first_layer_units(5)
gem_2  = load_gem_first_layer_units(2)

# %%
syn_50 = load_syn_first_layer_units(50)
syn_20 = load_syn_first_layer_units(20)
syn_10 = load_syn_first_layer_units(10)
syn_5  = load_syn_first_layer_units(5)
syn_2  = load_syn_first_layer_units(2)

# %%
rnd_50 = load_rnd_first_layer_units(50)
rnd_20 = load_rnd_first_layer_units(20)
rnd_10 = load_rnd_first_layer_units(10)
rnd_5  = load_rnd_first_layer_units(5)
rnd_2  = load_rnd_first_layer_units(2)

# %% [markdown]
# # Plot Gem-Miner

# %%
plot_units(gem_50, "gem-miner", 50)

# %%
plot_units(gem_20, "gem-miner", 20)

# %%
plot_units(gem_10, "gem-miner", 10)

# %%
plot_units(gem_5, "gem-miner", 5)

# %%
plot_units(gem_2, "gem-miner", 2)

# %% [markdown]
# # Synflow

# %%
plot_units(syn_50, "synflow", 50)

# %%
plot_units(syn_20, "synflow", 20)

# %%
plot_units(syn_10, "synflow", 10)

# %%
plot_units(syn_5, "synflow", 5)

# %%
plot_units(syn_2, "synflow", 2)

# %% [markdown]
# # Random

# %%
plot_units(rnd_50, "random", 50)

# %%
plot_units(rnd_20, "random", 20)

# %%
plot_units(rnd_10, "random", 10)

# %%
plot_units(rnd_5, "random", 5)

# %%
plot_units(rnd_2, "random", 2)

# %% [markdown]
# # Kernel analysis

# %% [markdown]
# ## 50% sparsity

# %% [markdown]
# ### load resnet-20 models

# %%
gem_model_50_21 = load_gemini_model("Resnet20", 50, 21)
gem_model_50_42 = load_gemini_model("Resnet20", 50, 42)
gem_model_50_63 = load_gemini_model("Resnet20", 50, 63)

syn_model_50_21 = load_synflow_model("Resnet20", 50, 21)
syn_model_50_42 = load_synflow_model("Resnet20", 50, 42)
syn_model_50_63 = load_synflow_model("Resnet20", 50, 63)

rnd_model_50_21 = load_random_model("Resnet20", 50, 21)
rnd_model_50_42 = load_random_model("Resnet20", 50, 42)
rnd_model_50_63 = load_random_model("Resnet20", 50, 63)

# %% [markdown]
# ### get filters

# %%
gem_fil_50_21 = get_filters(gem_model_50_21)
gem_fil_50_42 = get_filters(gem_model_50_42)
gem_fil_50_63 = get_filters(gem_model_50_63)

syn_fil_50_21 = get_filters(syn_model_50_21)
syn_fil_50_42 = get_filters(syn_model_50_42)
syn_fil_50_63 = get_filters(syn_model_50_63)

rnd_fil_50_21 = get_filters(rnd_model_50_21)
rnd_fil_50_42 = get_filters(rnd_model_50_42)
rnd_fil_50_63 = get_filters(rnd_model_50_63)

# %%
show_common_kernels(gem_fil_50_21, 20, (2,10), "Gem-Miner 50% seed 21")
show_common_kernels(gem_fil_50_42, 20, (2,10), "Gem-Miner 50% seed 42")
show_common_kernels(gem_fil_50_63, 20, (2,10), "Gem-Miner 50% seed 63")

# %%
show_common_kernels(syn_fil_50_21, 20, (2,10), "SynFlow 50% seed 21")
show_common_kernels(syn_fil_50_42, 20, (2,10), "SynFlow 50% seed 42")
show_common_kernels(syn_fil_50_63, 20, (2,10), "SynFlow 50% seed 63")

# %%
show_common_kernels(rnd_fil_50_21, 20, (2,10), "Random 50% seed 21")
show_common_kernels(rnd_fil_50_42, 20, (2,10), "Random 50% seed 42")
show_common_kernels(rnd_fil_50_63, 20, (2,10), "Random 50% seed 63")

# %% [markdown]
# ## 20% sparsity

# %% [markdown]
# ### load resnet-20 models

# %%
gem_model_20_21 = load_gemini_model("Resnet20", 20, 21)
gem_model_20_42 = load_gemini_model("Resnet20", 20, 42)
gem_model_20_63 = load_gemini_model("Resnet20", 20, 63)

syn_model_20_21 = load_synflow_model("Resnet20", 20, 21)
syn_model_20_42 = load_synflow_model("Resnet20", 20, 42)
syn_model_20_63 = load_synflow_model("Resnet20", 20, 63)

rnd_model_20_21 = load_random_model("Resnet20", 20, 21)
rnd_model_20_42 = load_random_model("Resnet20", 20, 42)
rnd_model_20_63 = load_random_model("Resnet20", 20, 63)

# %% [markdown]
# ### get filters

# %%
gem_fil_20_21 = get_filters(gem_model_20_21)
gem_fil_20_42 = get_filters(gem_model_20_42)
gem_fil_20_63 = get_filters(gem_model_20_63)

syn_fil_20_21 = get_filters(syn_model_20_21)
syn_fil_20_42 = get_filters(syn_model_20_42)
syn_fil_20_63 = get_filters(syn_model_20_63)

rnd_fil_20_21 = get_filters(rnd_model_20_21)
rnd_fil_20_42 = get_filters(rnd_model_20_42)
rnd_fil_20_63 = get_filters(rnd_model_20_63)

# %%
show_common_kernels(gem_fil_20_21, 20, (2,10), "Gem-Miner 20% seed 21")
show_common_kernels(gem_fil_20_42, 20, (2,10), "Gem-Miner 20% seed 42")
show_common_kernels(gem_fil_20_63, 20, (2,10), "Gem-Miner 20% seed 63")

# %%
show_common_kernels(syn_fil_20_21, 20, (2,10), "SynFlow 20% seed 21")
show_common_kernels(syn_fil_20_42, 20, (2,10), "SynFlow 20% seed 42")
show_common_kernels(syn_fil_20_63, 20, (2,10), "SynFlow 20% seed 63")

# %%
show_common_kernels(rnd_fil_20_21, 20, (2,10), "Random 20% seed 21")
show_common_kernels(rnd_fil_20_42, 20, (2,10), "Random 20% seed 42")
show_common_kernels(rnd_fil_20_63, 20, (2,10), "Random 20% seed 63")

# %% [markdown]
# ## 10% sparsity

# %% [markdown]
# ### load resnet-20 models

# %%
gem_model_10_21 = load_gemini_model("Resnet20", 10, 21)
gem_model_10_42 = load_gemini_model("Resnet20", 10, 42)
gem_model_10_63 = load_gemini_model("Resnet20", 10, 63)

syn_model_10_21 = load_synflow_model("Resnet20", 10, 21)
syn_model_10_42 = load_synflow_model("Resnet20", 10, 42)
syn_model_10_63 = load_synflow_model("Resnet20", 10, 63)

rnd_model_10_21 = load_random_model("Resnet20", 10, 21)
rnd_model_10_42 = load_random_model("Resnet20", 10, 42)
rnd_model_10_63 = load_random_model("Resnet20", 10, 63)

# %% [markdown]
# ### get filters

# %%
gem_fil_10_21 = get_filters(gem_model_10_21)
gem_fil_10_42 = get_filters(gem_model_10_42)
gem_fil_10_63 = get_filters(gem_model_10_63)

syn_fil_10_21 = get_filters(syn_model_10_21)
syn_fil_10_42 = get_filters(syn_model_10_42)
syn_fil_10_63 = get_filters(syn_model_10_63)

rnd_fil_10_21 = get_filters(rnd_model_10_21)
rnd_fil_10_42 = get_filters(rnd_model_10_42)
rnd_fil_10_63 = get_filters(rnd_model_10_63)

# %%
show_common_kernels(gem_fil_10_21, 20, (2,10), "Gem-Miner 10% seed 21")
show_common_kernels(gem_fil_10_42, 20, (2,10), "Gem-Miner 10% seed 42")
show_common_kernels(gem_fil_10_63, 20, (2,10), "Gem-Miner 10% seed 63")

# %%
show_common_kernels(syn_fil_10_21, 20, (2,10), "SynFlow 10% seed 21")
show_common_kernels(syn_fil_10_42, 20, (2,10), "SynFlow 10% seed 42")
show_common_kernels(syn_fil_10_63, 20, (2,10), "SynFlow 10% seed 63")

# %%
show_common_kernels(rnd_fil_10_21, 20, (2,10), "Random 10% seed 21")
show_common_kernels(rnd_fil_10_42, 20, (2,10), "Random 10% seed 42")
show_common_kernels(rnd_fil_10_63, 20, (2,10), "Random 10% seed 63")

# %% [markdown]
# ## 5% sparsity

# %% [markdown]
# ### load resnet-20 models

# %%
gem_model_5_21 = load_gemini_model("Resnet20", 5, 21)
gem_model_5_42 = load_gemini_model("Resnet20", 5, 42)
gem_model_5_63 = load_gemini_model("Resnet20", 5, 63)

syn_model_5_21 = load_synflow_model("Resnet20", 5, 21)
syn_model_5_42 = load_synflow_model("Resnet20", 5, 42)
syn_model_5_63 = load_synflow_model("Resnet20", 5, 63)

rnd_model_5_21 = load_random_model("Resnet20", 5, 21)
rnd_model_5_42 = load_random_model("Resnet20", 5, 42)
rnd_model_5_63 = load_random_model("Resnet20", 5, 63)

# %% [markdown]
# ### get filters

# %%
gem_fil_5_21 = get_filters(gem_model_5_21)
gem_fil_5_42 = get_filters(gem_model_5_42)
gem_fil_5_63 = get_filters(gem_model_5_63)

syn_fil_5_21 = get_filters(syn_model_5_21)
syn_fil_5_42 = get_filters(syn_model_5_42)
syn_fil_5_63 = get_filters(syn_model_5_63)

rnd_fil_5_21 = get_filters(rnd_model_5_21)
rnd_fil_5_42 = get_filters(rnd_model_5_42)
rnd_fil_5_63 = get_filters(rnd_model_5_63)

# %%
show_common_kernels(gem_fil_5_21, 20, (2,10), "Gem-Miner 5% seed 21")
show_common_kernels(gem_fil_5_42, 20, (2,10), "Gem-Miner 5% seed 42")
show_common_kernels(gem_fil_5_63, 20, (2,10), "Gem-Miner 5% seed 63")

# %%
show_common_kernels(syn_fil_5_21, 20, (2,10), "SynFlow 5% seed 21")
show_common_kernels(syn_fil_5_42, 20, (2,10), "SynFlow 5% seed 42")
show_common_kernels(syn_fil_5_63, 20, (2,10), "SynFlow 5% seed 63")

# %%
show_common_kernels(rnd_fil_5_21, 20, (2,10), "Random 5% seed 21")
show_common_kernels(rnd_fil_5_42, 20, (2,10), "Random 5% seed 42")
show_common_kernels(rnd_fil_5_63, 20, (2,10), "Random 5% seed 63")

# %% [markdown]
# ## 2% sparsity

# %% [markdown]
# ### load resnet-20 models

# %%
gem_model_2_21 = load_gemini_model("Resnet20", 2, 21)
gem_model_2_42 = load_gemini_model("Resnet20", 2, 42)
gem_model_2_63 = load_gemini_model("Resnet20", 2, 63)

syn_model_2_21 = load_synflow_model("Resnet20", 2, 21)
syn_model_2_42 = load_synflow_model("Resnet20", 2, 42)
syn_model_2_63 = load_synflow_model("Resnet20", 2, 63)

rnd_model_2_21 = load_random_model("Resnet20", 2, 21)
rnd_model_2_42 = load_random_model("Resnet20", 2, 42)
rnd_model_2_63 = load_random_model("Resnet20", 2, 63)

# %% [markdown]
# ### get filters

# %%
gem_fil_2_21 = get_filters(gem_model_2_21)
gem_fil_2_42 = get_filters(gem_model_2_42)
gem_fil_2_63 = get_filters(gem_model_2_63)

syn_fil_2_21 = get_filters(syn_model_2_21)
syn_fil_2_42 = get_filters(syn_model_2_42)
syn_fil_2_63 = get_filters(syn_model_2_63)

rnd_fil_2_21 = get_filters(rnd_model_2_21)
rnd_fil_2_42 = get_filters(rnd_model_2_42)
rnd_fil_2_63 = get_filters(rnd_model_2_63)

# %%
show_common_kernels(gem_fil_2_21, 20, (2,10), "Gem-Miner 2% seed 21")
show_common_kernels(gem_fil_2_42, 20, (2,10), "Gem-Miner 2% seed 42")
show_common_kernels(gem_fil_2_63, 20, (2,10), "Gem-Miner 2% seed 63")

# %%
show_common_kernels(syn_fil_2_21, 20, (2,10), "SynFlow 2% seed 21")
show_common_kernels(syn_fil_2_42, 20, (2,10), "SynFlow 2% seed 42")
show_common_kernels(syn_fil_2_63, 20, (2,10), "SynFlow 2% seed 63")

# %%
show_common_kernels(rnd_fil_2_21, 20, (2,10), "Random 2% seed 21")
show_common_kernels(rnd_fil_2_42, 20, (2,10), "Random 2% seed 42")
show_common_kernels(rnd_fil_2_63, 20, (2,10), "Random 2% seed 63")
